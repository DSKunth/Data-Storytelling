# %%
import pandas as pd
import numpy as np
from ast import literal_eval
import ast
import re
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# %%
df = pd.read_csv('movies_metadata.csv', low_memory=False)
df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ... release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %%
df[df['production_countries'].isnull()]
# Out:
#        adult                              belongs_to_collection budget  \
# 19729  False                                                NaN      0
# 29502  False  {'id': 122661, 'name': 'Mardock Scramble Colle...      0
# 35586  False                                                NaN      0
#
#                                                   genres  \
# 19729  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 29502  [{'id': 16, 'name': 'Animation'}, {'id': 878, ...
# 35586  [{'id': 10770, 'name': 'TV Movie'}, {'id': 28,...
#
#                             homepage      id    imdb_id original_language  \
# 19729                            NaN   82663  tt0113002                en
# 29502  http://m-scramble.jp/exhaust/  122662  tt2423504                ja
# 35586                            NaN  249260  tt2622826                en
#
#          original_title                                           overview  \
# 19729      Midnight Man  British soldiers force a recently captured IRA...
# 29502  マルドゥック・スクランブル 排気         Third film of the Mardock Scramble series.
# 35586  Avalanche Sharks  A group of skiers are terrorized during spring...
#
#        ... release_date revenue runtime spoken_languages status  tagline  \
# 19729  ...          NaN     NaN     NaN              NaN    NaN      NaN
# 29502  ...          NaN     NaN     NaN              NaN    NaN      NaN
# 35586  ...          NaN     NaN     NaN              NaN    NaN      NaN
#
#        title video vote_average vote_count
# 19729    NaN   NaN          NaN        NaN
# 29502    NaN   NaN          NaN        NaN
# 35586    NaN   NaN          NaN        NaN
#
# [3 rows x 24 columns]

# %%
df.production_countries.sample(30)
# Out:
# 21520                                                   []
# 18645              [{'iso_3166_1': 'JP', 'name': 'Japan'}]
# 12166    [{'iso_3166_1': 'US', 'name': 'United States o...
# 30886    [{'iso_3166_1': 'JP', 'name': 'Japan'}, {'iso_...
# 23226                                                   []
# 40921                                                   []
# 29297              [{'iso_3166_1': 'IT', 'name': 'Italy'}]
# 12466            [{'iso_3166_1': 'IS', 'name': 'Iceland'}]
# 10245    [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso...
# 13741     [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]
# 15151    [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso...
# 2699     [{'iso_3166_1': 'US', 'name': 'United States o...
# 6798     [{'iso_3166_1': 'US', 'name': 'United States o...
# 42331    [{'iso_3166_1': 'BR', 'name': 'Brazil'}, {'iso...
# 17188             [{'iso_3166_1': 'SE', 'name': 'Sweden'}]
# 338      [{'iso_3166_1': 'US', 'name': 'United States o...
# 12941    [{'iso_3166_1': 'US', 'name': 'United States o...
# 12486          [{'iso_3166_1': 'AU', 'name': 'Australia'}]
# 5171     [{'iso_3166_1': 'US', 'name': 'United States o...
# 35468                                                   []
# 2991     [{'iso_3166_1': 'US', 'name': 'United States o...
# 24089    [{'iso_3166_1': 'US', 'name': 'United States o...
# 43631                                                   []
# 24704    [{'iso_3166_1': 'US', 'name': 'United States o...
# 19632              [{'iso_3166_1': 'JP', 'name': 'Japan'}]
# 38976             [{'iso_3166_1': 'FR', 'name': 'France'}]
# 9330     [{'iso_3166_1': 'DE', 'name': 'Germany'}, {'is...
# 3881     [{'iso_3166_1': 'US', 'name': 'United States o...
# 37062              [{'iso_3166_1': 'IN', 'name': 'India'}]
# 24277              [{'iso_3166_1': 'JP', 'name': 'Japan'}]
# Name: production_countries, dtype: object

# %%
df.spoken_languages.sample(30)
# Out:
# 33589    [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 17333                                                   []
# 6056              [{'iso_639_1': 'en', 'name': 'English'}]
# 10365               [{'iso_639_1': 'da', 'name': 'Dansk'}]
# 13589             [{'iso_639_1': 'en', 'name': 'English'}]
# 40255                 [{'iso_639_1': 'zh', 'name': '普通话'}]
# 12611             [{'iso_639_1': 'en', 'name': 'English'}]
# 24168             [{'iso_639_1': 'de', 'name': 'Deutsch'}]
# 18121                                                   []
# 25891    [{'iso_639_1': 'de', 'name': 'Deutsch'}, {'iso...
# 26456             [{'iso_639_1': 'en', 'name': 'English'}]
# 9170                  [{'iso_639_1': 'ja', 'name': '日本語'}]
# 5910     [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 18378    [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 32737             [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]
# 29320             [{'iso_639_1': 'en', 'name': 'English'}]
# 6137              [{'iso_639_1': 'en', 'name': 'English'}]
# 42514             [{'iso_639_1': 'en', 'name': 'English'}]
# 18353             [{'iso_639_1': 'es', 'name': 'Español'}]
# 28486             [{'iso_639_1': 'en', 'name': 'English'}]
# 39849             [{'iso_639_1': 'en', 'name': 'English'}]
# 29922             [{'iso_639_1': 'en', 'name': 'English'}]
# 3313              [{'iso_639_1': 'en', 'name': 'English'}]
# 32838                                                   []
# 41156                                                   []
# 22027             [{'iso_639_1': 'en', 'name': 'English'}]
# 23906             [{'iso_639_1': 'en', 'name': 'English'}]
# 38606             [{'iso_639_1': 'en', 'name': 'English'}]
# 4171              [{'iso_639_1': 'en', 'name': 'English'}]
# 31896              [{'iso_639_1': 'pl', 'name': 'Polski'}]
# Name: spoken_languages, dtype: object

# %%
# checking for distorted records
new_df = df[~df["adult"].str.contains('False') & ~df["adult"].str.contains('True')]
new_df
# Out:
#                                                    adult  \
# 19730                                 - Written by Ørnås
# 29503   Rune Balot goes to a casino connected to the ...
# 35587   Avalanche Sharks tells the story of a bikini ...
#
#       belongs_to_collection                            budget  \
# 19730              0.065736  /ff9qCepilowshEtG2GYWwzt2bs4.jpg
# 29503              1.931659  /zV8bHuSL6WXoD6FWogP9j4x80bL.jpg
# 35587              2.185485  /zaSf5OG7V8X8gqFvly88zDdRm46.jpg
#
#                                                   genres  \
# 19730  [{'name': 'Carousel Productions', 'id': 11176}...
# 29503  [{'name': 'Aniplex', 'id': 2883}, {'name': 'Go...
# 35587  [{'name': 'Odyssey Media', 'id': 17161}, {'nam...
#
#                                                 homepage          id imdb_id  \
# 19730  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...  1997-08-20       0
# 29503  [{'iso_3166_1': 'US', 'name': 'United States o...  2012-09-29       0
# 35587           [{'iso_3166_1': 'CA', 'name': 'Canada'}]  2014-01-01       0
#
#       original_language                            original_title  overview  \
# 19730             104.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 29503              68.0      [{'iso_639_1': 'ja', 'name': '日本語'}]  Released
# 35587              82.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#        ... release_date revenue runtime spoken_languages status  tagline  \
# 19730  ...            1     NaN     NaN              NaN    NaN      NaN
# 29503  ...           12     NaN     NaN              NaN    NaN      NaN
# 35587  ...           22     NaN     NaN              NaN    NaN      NaN
#
#        title video vote_average vote_count
# 19730    NaN   NaN          NaN        NaN
# 29503    NaN   NaN          NaN        NaN
# 35587    NaN   NaN          NaN        NaN
#
# [3 rows x 24 columns]

# %%
#Using Apply to search for substring in all dataframe columns
substring = '/uUi23HjvDFYGfuVlCBGozUY1Ab4.jpg'
df[df.apply(lambda row: row.astype(str).str.contains(substring, case=False).any(), axis=1)]
# Out:
#      adult belongs_to_collection budget genres homepage      id    imdb_id  \
# 126  False                   NaN      0     []      NaN  290157  tt0110217
#
#     original_language  original_title  \
# 126                en  Jupiter's Wife
#
#                                               overview  ... release_date  \
# 126  Michel Negroponte, a documentary filmmaker, me...  ...   1995-01-01
#
#     revenue runtime spoken_languages    status                       tagline  \
# 126     0.0    87.0               []  Released  A Haunting Real Life Mystery
#
#               title  video vote_average vote_count
# 126  Jupiter's Wife  False          0.0        0.0
#
# [1 rows x 24 columns]

# %%
substring = '/uUi23HjvDFYGfuVlCBGozUY1Ab4.jpg'
df[df.apply(lambda row: row.astype(str).str.contains(substring, case=False).any(), axis=1)]
# Out:
#      adult belongs_to_collection budget genres homepage      id    imdb_id  \
# 126  False                   NaN      0     []      NaN  290157  tt0110217
#
#     original_language  original_title  \
# 126                en  Jupiter's Wife
#
#                                               overview  ... release_date  \
# 126  Michel Negroponte, a documentary filmmaker, me...  ...   1995-01-01
#
#     revenue runtime spoken_languages    status                       tagline  \
# 126     0.0    87.0               []  Released  A Haunting Real Life Mystery
#
#               title  video vote_average vote_count
# 126  Jupiter's Wife  False          0.0        0.0
#
# [1 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
#  14  release_date           45379 non-null  object
#  15  revenue                45460 non-null  float64
#  16  runtime                45203 non-null  float64
#  17  spoken_languages       45460 non-null  object
#  18  status                 45379 non-null  object
#  19  tagline                20412 non-null  object
#  20  title                  45460 non-null  object
#  21  video                  45460 non-null  object
#  22  vote_average           45460 non-null  float64
#  23  vote_count             45460 non-null  float64
# dtypes: float64(4), object(20)
# memory usage: 8.3+ MB

# %%
# select the variables/columns to explore and store in df_movies dataframe
target_columns = [
    'original_title', 'overview', 'revenue', 'budget', 'genres', 'original_language', 'popularity', 
    'vote_average', 'vote_count', 'production_countries']

df_movies = df[target_columns]

# %%
df_movies[df_movies['original_title'] == 'Big Hero 6']
# Out:
#       original_title                                           overview  \
# 24455     Big Hero 6  The special bond that develops between plus-si...
#
#            revenue     budget  \
# 24455  652105443.0  165000000
#
#                                                   genres original_language  \
# 24455  [{'id': 12, 'name': 'Adventure'}, {'id': 10751...                en
#
#        popularity  vote_average  vote_count  \
# 24455  213.849907           7.8      6289.0
#
#                                     production_countries
# 24455  [{'iso_3166_1': 'US', 'name': 'United States o...

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   original_title        45466 non-null  object
#  1   overview              44512 non-null  object
#  2   revenue               45460 non-null  float64
#  3   budget                45466 non-null  object
#  4   genres                45466 non-null  object
#  5   original_language     45455 non-null  object
#  6   popularity            45461 non-null  object
#  7   vote_average          45460 non-null  float64
#  8   vote_count            45460 non-null  float64
#  9   production_countries  45463 non-null  object
# dtypes: float64(3), object(7)
# memory usage: 3.5+ MB

# %%
df_movies.sample(20)
# Out:
#                     original_title  \
# 2642                       Frances
# 20754         Educazione siberiana
# 34497                     Wildlike
# 28573                     रान्झाना
# 40304            Out of This World
# 21954                     Bẫy Rồng
# 17925            The Living Desert
# 37154                         Choo
# 42510            Banović Strahinja
# 14618           The Sun Also Rises
# 14949                 Combat Shock
# 21813                  Zombie High
# 33598               Amore e rabbia
# 41150      The Autopsy of Jane Doe
# 26825                 The Big Land
# 40181  3 Hati Dua Dunia Satu Cinta
# 40312                     Ripoux 3
# 27936         High School Hellcats
# 4321                    Adanggaman
# 12591                      Redbelt
#
#                                                 overview     revenue   budget  \
# 2642   The true story of Frances Farmer's meteoric ri...   5000000.0        0
# 20754  The story of a gang of children growing up in ...         0.0        0
# 34497  Fourteen-year-old Mackenzie is sent to live wi...         0.0        0
# 28573  A small-town boy needs to break through the cl...  18000000.0  6400000
# 40304  After struggling to become a success, Betty Mi...         0.0        0
# 21954  Trinh, a mercenary, must complete a series of ...         0.0        0
# 17925  The Living Desert was the first feature-length...         0.0        0
# 37154  Dhep (Andy-Watchra Thungkaprasert) is a travel...         0.0        0
# 42510  Banovic Strahinja takes place during the middl...         0.0        0
# 14618  A group of disillusioned American expatriate w...         0.0        0
# 14949  A dangerously disturbed Vietnam veteran strugg...         0.0    40000
# 21813  A woman goes to previously all-male boarding s...         0.0        0
# 33598  Five short stories with contemporary settings....         0.0        0
# 41150  Father and son coroners receive a mysterious u...   5972942.0        0
# 26825  Back home in Texas following the Civil War, fo...         0.0        0
# 40181  A love story of a Moslem freelance journalist ...         0.0        0
# 40312  Voilà dix ans que les chemins de René et de Fr...         0.0        0
# 27936  The Hellcats are an all-female gang bent on bu...         0.0        0
# 4321   In West Africa during the late 17th century, K...        28.0        0
# 12591  Is there room for principle in Los Angeles? Mi...         0.0  7000000
#
#                                                   genres original_language  \
# 2642                       [{'id': 18, 'name': 'Drama'}]                en
# 20754  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...                it
# 34497  [{'id': 12, 'name': 'Adventure'}, {'id': 18, '...                en
# 28573  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...                hi
# 40304  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...                en
# 21954  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...                vi
# 17925                [{'id': 99, 'name': 'Documentary'}]                en
# 37154  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...                th
# 42510  [{'id': 36, 'name': 'History'}, {'id': 18, 'na...                hr
# 14618  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...                en
# 14949  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...                en
# 21813  [{'id': 35, 'name': 'Comedy'}, {'id': 27, 'nam...                en
# 33598                      [{'id': 18, 'name': 'Drama'}]                it
# 41150  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...                en
# 26825                    [{'id': 37, 'name': 'Western'}]                en
# 40181                                                 []                en
# 40312                     [{'id': 35, 'name': 'Comedy'}]                en
# 27936                      [{'id': 18, 'name': 'Drama'}]                en
# 4321   [{'id': 18, 'name': 'Drama'}, {'id': 10769, 'n...                fr
# 12591                      [{'id': 18, 'name': 'Drama'}]                en
#
#       popularity  vote_average  vote_count  \
# 2642    2.077869           7.1        24.0
# 20754  13.631223           6.7       138.0
# 34497  10.754914           6.6        44.0
# 28573   1.856101           6.3        34.0
# 40304   0.180517           5.0         2.0
# 21954   0.743727           4.9         8.0
# 17925   0.553225           6.4         5.0
# 37154   0.416474           6.0         3.0
# 42510   0.365618           4.8         2.0
# 14618   1.368063           5.4         6.0
# 14949   1.640696           6.4        14.0
# 21813   1.329736           3.8         6.0
# 33598   0.662422           5.3         8.0
# 41150  31.772396           6.3       799.0
# 26825   0.164676           6.0         4.0
# 40181   0.005882           0.0         0.0
# 40312   2.800132           5.1        16.0
# 27936   0.318612           5.3         3.0
# 4321    0.071765           7.5         2.0
# 12591   5.130795           6.4        77.0
#
#                                     production_countries
# 2642   [{'iso_3166_1': 'US', 'name': 'United States o...
# 20754            [{'iso_3166_1': 'IT', 'name': 'Italy'}]
# 34497  [{'iso_3166_1': 'US', 'name': 'United States o...
# 28573            [{'iso_3166_1': 'IN', 'name': 'India'}]
# 40304  [{'iso_3166_1': 'US', 'name': 'United States o...
# 21954          [{'iso_3166_1': 'VN', 'name': 'Vietnam'}]
# 17925  [{'iso_3166_1': 'US', 'name': 'United States o...
# 37154         [{'iso_3166_1': 'TH', 'name': 'Thailand'}]
# 42510  [{'iso_3166_1': 'HR', 'name': 'Croatia'}, {'is...
# 14618  [{'iso_3166_1': 'US', 'name': 'United States o...
# 14949  [{'iso_3166_1': 'US', 'name': 'United States o...
# 21813                                                 []
# 33598            [{'iso_3166_1': 'IT', 'name': 'Italy'}]
# 41150  [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...
# 26825  [{'iso_3166_1': 'US', 'name': 'United States o...
# 40181                                                 []
# 40312           [{'iso_3166_1': 'FR', 'name': 'France'}]
# 27936  [{'iso_3166_1': 'US', 'name': 'United States o...
# 4321   [{'iso_3166_1': 'CI', 'name': "Cote D'Ivoire"}...
# 12591  [{'iso_3166_1': 'US', 'name': 'United States o...

# %%
df_movies['vote_average'].value_counts()
# Out:
# 0.0    2998
# 6.0    2468
# 5.0    2001
# 7.0    1886
# 6.5    1722
#        ...
# 9.4       3
# 9.6       1
# 9.8       1
# 0.7       1
# 1.1       1
# Name: vote_average, Length: 92, dtype: int64

# %%
df_movies['vote_count'].value_counts()
# Out:
# 1.0       3264
# 2.0       3132
# 0.0       2899
# 3.0       2787
# 4.0       2480
#           ...
# 2755.0       1
# 1187.0       1
# 4200.0       1
# 3322.0       1
# 2712.0       1
# Name: vote_count, Length: 1820, dtype: int64

# %%
df['popularity'].value_counts()
# Out:
# 0.0         66
# 1e-06       56
# 0.000308    43
# 0.00022     40
# 0.001177    38
#             ..
# 4.762242     1
# 6.173752     1
# 0.645652     1
# 0.556292     1
# 0.163015     1
# Name: popularity, Length: 43758, dtype: int64

# %%
df['popularity'].describe()
# Out:
# count     45461
# unique    43758
# top         0.0
# freq         66
# Name: popularity, dtype: object

# %%
df_movies['production_countries'].value_counts()
# Out:
# [{'iso_3166_1': 'US', 'name': 'United States of America'}]                                                                                                          17851
# []                                                                                                                                                                   6282
# [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]                                                                                                                     2238
# [{'iso_3166_1': 'FR', 'name': 'France'}]                                                                                                                             1654
# [{'iso_3166_1': 'JP', 'name': 'Japan'}]                                                                                                                              1356
#                                                                                                                                                                     ...
# [{'iso_3166_1': 'AU', 'name': 'Australia'}, {'iso_3166_1': 'ZA', 'name': 'South Africa'}]                                                                               1
# [{'iso_3166_1': 'RO', 'name': 'Romania'}, {'iso_3166_1': 'GB', 'name': 'United Kingdom'}, {'iso_3166_1': 'CA', 'name': 'Canada'}]                                       1
# [{'iso_3166_1': 'FI', 'name': 'Finland'}, {'iso_3166_1': 'DE', 'name': 'Germany'}, {'iso_3166_1': 'NL', 'name': 'Netherlands'}]                                         1
# [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso_3166_1': 'DK', 'name': 'Denmark'}, {'iso_3166_1': 'ES', 'name': 'Spain'}, {'iso_3166_1': 'SE', 'name': 'Sweden'}]        1
# [{'iso_3166_1': 'EG', 'name': 'Egypt'}, {'iso_3166_1': 'IT', 'name': 'Italy'}, {'iso_3166_1': 'US', 'name': 'United States of America'}]                                1
# Name: production_countries, Length: 2393, dtype: int64

# %%
df_movies['genres'].value_counts()
# Out:
# [{'id': 18, 'name': 'Drama'}]                                                                                                         5000
# [{'id': 35, 'name': 'Comedy'}]                                                                                                        3621
# [{'id': 99, 'name': 'Documentary'}]                                                                                                   2723
# []                                                                                                                                    2442
# [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}]                                                                       1301
#                                                                                                                                       ...
# [{'id': 28, 'name': 'Action'}, {'id': 18, 'name': 'Drama'}, {'id': 35, 'name': 'Comedy'}, {'id': 99, 'name': 'Documentary'}]             1
# [{'id': 10752, 'name': 'War'}, {'id': 18, 'name': 'Drama'}, {'id': 36, 'name': 'History'}, {'id': 53, 'name': 'Thriller'}]               1
# [{'id': 27, 'name': 'Horror'}, {'id': 18, 'name': 'Drama'}, {'id': 36, 'name': 'History'}, {'id': 53, 'name': 'Thriller'}]               1
# [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'name': 'Crime'}, {'id': 28, 'name': 'Action'}, {'id': 18, 'name': 'Drama'}]                   1
# [{'id': 10751, 'name': 'Family'}, {'id': 16, 'name': 'Animation'}, {'id': 10749, 'name': 'Romance'}, {'id': 35, 'name': 'Comedy'}]       1
# Name: genres, Length: 4069, dtype: int64

# %%
df_movies['original_language'].value_counts()
# Out:
# en       32269
# fr        2438
# it        1529
# ja        1350
# de        1080
#          ...
# zu           1
# qu           1
# 104.0        1
# la           1
# si           1
# Name: original_language, Length: 92, dtype: int64

# %% [markdown]
# Compute IMDb score using IMDB's weighted rating formula, store in a new column imdb_score
#
# ![imdb_WR.png](attachment:imdb_WR.png)
# ![WR-2.png](attachment:WR-2.png)

# %%
C = df_movies['vote_average'].mean()
m = df_movies['vote_count'].quantile(0.9)

q_movies = df_movies.copy().loc[df_movies['vote_count'] >= m]

def weighted_rating(x, m=m, C=C):
    v = x['vote_count']
    R = x['vote_average']
    
    #computation based on IMDB formula
    return (v/(v+m) * R) + (m/(v+m) * C)

print('The mean vote across the whole dataset - ', C)
print('The minimum votes required to be listed in the top 250 - ', m)
# Out:
# The mean vote across the whole dataset -  5.618207215133889
# The minimum votes required to be listed in the top 250 -  160.0

# %%
# define a new feature imdb_score, calculate values using weighted_rating required to be considered
q_movies['imdb_score'] = q_movies.apply(weighted_rating, axis=1)
q_movies.head()
# Out:
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 4  Father of the Bride Part II
# 5                         Heat
# 8                 Sudden Death
#
#                                             overview      revenue    budget  \
# 0  Led by Woody, Andy's toys live happily in his ...  373554033.0  30000000
# 1  When siblings Judy and Peter discover an encha...  262797249.0  65000000
# 4  Just when George Banks has recovered from his ...   76578911.0         0
# 5  Obsessive master thief, Neil McCauley leads a ...  187436818.0  60000000
# 8  International action superstar Jean Claude Van...   64350171.0  35000000
#
#                                               genres original_language  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...                en
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...                en
# 4                     [{'id': 35, 'name': 'Comedy'}]                en
# 5  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...                en
# 8  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...                en
#
#   popularity  vote_average  vote_count  \
# 0  21.946943           7.7      5415.0
# 1  17.015539           6.9      2413.0
# 4   8.387519           5.7       173.0
# 5  17.924927           7.7      1886.0
# 8    5.23158           5.5       174.0
#
#                                 production_countries  imdb_score
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...    7.640253
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...    6.820293
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...    5.660700
# 5  [{'iso_3166_1': 'US', 'name': 'United States o...    7.537201
# 8  [{'iso_3166_1': 'US', 'name': 'United States o...    5.556626

# %%
q_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4555 entries, 0 to 45343
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   original_title        4555 non-null   object
#  1   overview              4550 non-null   object
#  2   revenue               4555 non-null   float64
#  3   budget                4555 non-null   object
#  4   genres                4555 non-null   object
#  5   original_language     4555 non-null   object
#  6   popularity            4555 non-null   object
#  7   vote_average          4555 non-null   float64
#  8   vote_count            4555 non-null   float64
#  9   production_countries  4555 non-null   object
#  10  imdb_score            4555 non-null   float64
# dtypes: float64(4), object(7)
# memory usage: 427.0+ KB

# %% [markdown]
# q_movies['popularity'] = pd.to_numeric(q_movies['popularity'],errors = 'coerce')
# q_movies.info()

# %%
q_movies['popularity'] = q_movies['popularity'].astype(float)

# %% [markdown]
# q_movies['budget'] = pd.to_numeric(q_movies['budget'],errors = 'coerce')
# q_movies.info()

# %%
q_movies['budget'] = q_movies['budget'].astype(float)

# %%
q_movies['overview'].isna().value_counts()
# Out:
# False    4550
# True        5
# Name: overview, dtype: int64

# %%
# create function to extract genre and country by converting from json list into list of strings

def json_to_arr(cell, wanted = 'name'):
    cell = literal_eval(cell)
    if cell == [] or (isinstance(cell, float) and cell.isna()):
        return np.nan
    result = []
    counter = 0
    for element in cell:
        if counter < 3:
            result.append(element[wanted])
            counter += 1
        else:
            break
    return result[:3]

# %%
q_movies[['genres']] = df[['genres']].applymap(json_to_arr)
q_movies[['production_countries']] = q_movies[['production_countries']].applymap(lambda row:
                                                                                json_to_arr(row, "iso_3166_1"))

# %%
q_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4555 entries, 0 to 45343
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   original_title        4555 non-null   object
#  1   overview              4550 non-null   object
#  2   revenue               4555 non-null   float64
#  3   budget                4555 non-null   float64
#  4   genres                4554 non-null   object
#  5   original_language     4555 non-null   object
#  6   popularity            4555 non-null   float64
#  7   vote_average          4555 non-null   float64
#  8   vote_count            4555 non-null   float64
#  9   production_countries  4551 non-null   object
#  10  imdb_score            4555 non-null   float64
# dtypes: float64(6), object(5)
# memory usage: 427.0+ KB

# %%
q_movies.head()
# Out:
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 4  Father of the Bride Part II
# 5                         Heat
# 8                 Sudden Death
#
#                                             overview      revenue      budget  \
# 0  Led by Woody, Andy's toys live happily in his ...  373554033.0  30000000.0
# 1  When siblings Judy and Peter discover an encha...  262797249.0  65000000.0
# 4  Just when George Banks has recovered from his ...   76578911.0         0.0
# 5  Obsessive master thief, Neil McCauley leads a ...  187436818.0  60000000.0
# 8  International action superstar Jean Claude Van...   64350171.0  35000000.0
#
#                           genres original_language  popularity  vote_average  \
# 0    [Animation, Comedy, Family]                en   21.946943           7.7
# 1   [Adventure, Fantasy, Family]                en   17.015539           6.9
# 4                       [Comedy]                en    8.387519           5.7
# 5         [Action, Crime, Drama]                en   17.924927           7.7
# 8  [Action, Adventure, Thriller]                en    5.231580           5.5
#
#    vote_count production_countries  imdb_score
# 0      5415.0                 [US]    7.640253
# 1      2413.0                 [US]    6.820293
# 4       173.0                 [US]    5.660700
# 5      1886.0                 [US]    7.537201
# 8       174.0                 [US]    5.556626

# %% [markdown]
# df_1_clean.loc[df_1_clean['tweet_id'] == '682962037429899265', 'rating_numerator'] = 10

# %%
q_movies.loc[q_movies['original_language'] == 'da', 'original_language'] = 'Danish'
q_movies.loc[q_movies['original_language'] == 'de', 'original_language'] = 'German'
q_movies.loc[q_movies['original_language'] == 'en', 'original_language'] = 'English'
q_movies.loc[q_movies['original_language'] == 'es', 'original_language'] = 'Spanish'
q_movies.loc[q_movies['original_language'] == 'fr', 'original_language'] = 'French'
q_movies.loc[q_movies['original_language'] == 'hi', 'original_language'] = 'Hindi'
q_movies.loc[q_movies['original_language'] == 'it', 'original_language'] = 'Italian'
q_movies.loc[q_movies['original_language'] == 'ja', 'original_language'] = 'Japanese'
q_movies.loc[q_movies['original_language'] == 'ko', 'original_language'] = 'Korean'
q_movies.loc[q_movies['original_language'] == 'pt', 'original_language'] = 'Portuguese'
q_movies.loc[q_movies['original_language'] == 'sv', 'original_language'] = 'Svenska'

# %%
q_movies['original_language'].value_counts()
# Out:
# English       4077
# French         177
# Japanese        65
# Italian         56
# Spanish         38
# German          27
# Korean          19
# cn              18
# Danish          14
# Svenska         11
# zh              11
# ru               8
# Hindi            7
# Portuguese       6
# id               3
# th               3
# no               3
# sr               2
# nl               2
# hu               1
# tr               1
# pl               1
# he               1
# fa               1
# nb               1
# el               1
# te               1
# Name: original_language, dtype: int64

# %% [markdown]
# #convert genres from json list into list of strings
# q_movies['genres'] = q_movies['genres'].fillna('[]').apply(literal_eval).apply(lambda x: [i['name'] for i in x] if isinstance(x, list) else [])

# %% [markdown]
# #define function to extract genres from json lists using regex
# all_genres = []
# def prune_genre(data):
#     genre = []
#     pattern = 'name\': \'[a-zA-Z]+\''
#     found = re.findall(pattern, data)
#     if found:
#         for i in range(len(found)):
#             genre.append(found[i][8:-1])
#             if found[i][8:-1] not in all_genres:
#                 all_genres.append(found[i][8:-1])
#     else:
#         return []
#     return genre

# %% [markdown]
# q_movies['genre'] = q_movies['genres'].apply(prune_genre)

# %%
q_movies = q_movies.sort_values('imdb_score', ascending=False)
q_movies.head(20)
# Out:
#                         original_title  \
# 314           The Shawshank Redemption
# 834                      The Godfather
# 10309      Dilwale Dulhania Le Jayenge
# 12481                  The Dark Knight
# 2843                        Fight Club
# 292                       Pulp Fiction
# 522                   Schindler's List
# 23673                         Whiplash
# 5481                          千と千尋の神隠し
# 2211                   La vita è bella
# 1178            The Godfather: Part II
# 1152   One Flew Over the Cuckoo's Nest
# 351                       Forrest Gump
# 1154           The Empire Strikes Back
# 1176                            Psycho
# 18465                     Intouchables
# 40251                            君の名は。
# 289                               Léon
# 3030                    The Green Mile
# 1170                        GoodFellas
#
#                                                 overview       revenue  \
# 314    Framed in the 1940s for the double murder of h...  2.834147e+07
# 834    Spanning the years 1945 to 1955, a chronicle o...  2.450664e+08
# 10309  Raj is a rich, carefree, happy-go-lucky second...  1.000000e+08
# 12481  Batman raises the stakes in his war on crime. ...  1.004558e+09
# 2843   A ticking-time-bomb insomniac and a slippery s...  1.008538e+08
# 292    A burger-loving hit man, his philosophical par...  2.139288e+08
# 522    The true story of how businessman Oskar Schind...  3.213656e+08
# 23673  Under the direction of a ruthless instructor, ...  1.309200e+07
# 5481   A ten year old girl who wanders away from her ...  2.749251e+08
# 2211   A touching story of an Italian book seller of ...  2.294000e+08
# 1178   In the continuing saga of the Corleone crime f...  4.754284e+07
# 1152   While serving time for insanity at a state men...  1.089813e+08
# 351    A man with a low IQ has accomplished great thi...  6.779454e+08
# 1154   The epic saga continues as Luke Skywalker, in ...  5.384000e+08
# 1176   When larcenous real estate clerk Marion Crane ...  3.200000e+07
# 18465  A true story of two men who should never have ...  4.264809e+08
# 40251  High schoolers Mitsuha and Taki are complete s...  3.552983e+08
# 289    Leon, the top hit man in New York, has earned ...  4.528497e+07
# 3030   A supernatural tale set on death row in a Sout...  2.846000e+08
# 1170   The true story of Henry Hill, a half-Irish, ha...  4.683639e+07
#
#             budget                                genres original_language  \
# 314     25000000.0                        [Drama, Crime]           English
# 834      6000000.0                        [Drama, Crime]           English
# 10309   13200000.0              [Comedy, Drama, Romance]             Hindi
# 12481  185000000.0                [Drama, Action, Crime]           English
# 2843    63000000.0                               [Drama]           English
# 292      8000000.0                     [Thriller, Crime]           English
# 522     22000000.0                 [Drama, History, War]           English
# 23673    3300000.0                               [Drama]           English
# 5481    15000000.0       [Fantasy, Adventure, Animation]          Japanese
# 2211    20000000.0                       [Comedy, Drama]           Italian
# 1178    13000000.0                        [Drama, Crime]           English
# 1152     3000000.0                               [Drama]           English
# 351     55000000.0              [Comedy, Drama, Romance]           English
# 1154    18000000.0  [Adventure, Action, Science Fiction]           English
# 1176      806948.0             [Drama, Horror, Thriller]           English
# 18465   13000000.0                       [Drama, Comedy]            French
# 40251          0.0           [Romance, Animation, Drama]          Japanese
# 289     16000000.0              [Thriller, Crime, Drama]            French
# 3030    60000000.0               [Fantasy, Drama, Crime]           English
# 1170    25000000.0                        [Drama, Crime]           English
#
#        popularity  vote_average  vote_count production_countries  imdb_score
# 314     51.645403           8.5      8358.0                 [US]    8.445869
# 834     41.109264           8.5      6024.0                 [US]    8.425439
# 10309   34.457024           9.1       661.0                 [IN]    8.421453
# 12481  123.167259           8.3     12269.0             [GB, US]    8.265477
# 2843    63.869599           8.3      9678.0             [DE, US]    8.256385
# 292    140.950236           8.3      8670.0                 [US]    8.251406
# 522     41.725123           8.3      4436.0                 [US]    8.206639
# 23673   64.299990           8.3      4376.0                 [US]    8.205404
# 5481    41.048867           8.3      3968.0                 [JP]    8.196055
# 2211    39.394970           8.3      3643.0                 [IT]    8.187171
# 1178    36.629307           8.3      3418.0                 [US]    8.180076
# 1152    35.529554           8.3      3001.0                 [US]    8.164256
# 351     48.307194           8.2      8147.0                 [US]    8.150272
# 1154    19.470959           8.2      5998.0                 [US]    8.132919
# 1176    36.826309           8.3      2405.0                 [US]    8.132715
# 18465   16.086919           8.2      5410.0                 [FR]    8.125837
# 40251   34.461252           8.5      1030.0                 [JP]    8.112532
# 289     20.477329           8.2      4293.0             [FR, US]    8.107234
# 3030    19.966780           8.2      4166.0                 [US]    8.104511
# 1170    15.424092           8.2      3211.0                 [US]    8.077459

# %%
top250movies_score = q_movies[['original_title', 'genres', 
                               'popularity', 'original_language', 'production_countries', 'imdb_score']].head(250)

# %%
top250movies_score.to_csv('top_movies_score.csv', index = False)

# %%
top250movies_score.describe()
# Out:
#        popularity  imdb_score
# count  250.000000  250.000000
# mean    21.847606    7.680821
# std     23.954822    0.242204
# min      0.010902    7.376555
# 25%     12.136232    7.481305
# 50%     15.812775    7.613630
# 75%     21.719981    7.825773
# max    213.849907    8.445869

# %%
plt.hist(data=top250movies_score, x = 'popularity');

# %%
bins = np.arange(0, top250movies_score['popularity'].max()+0.01, 1)
plt.figure(figsize=[10, 8])
plt.hist(data=top250movies_score, x = 'popularity', bins = bins);
plt.xlabel('Popularity', size = 12);
plt.ylabel('Number of Movies', size = 12)
plt.title('Popularity Distribution of the Top 250 Movies based on IMDb Score', size = 15);

# %% [markdown]
# top250movies_score.loc[top250movies_score['production_countries'] == '682962037429899265', 'rating_numerator'] = 10

# %%
top250movies_score['genres'].value_counts()[:10]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [Drama]                         21
# [Drama, Crime]                   9
# [Drama, Romance]                 9
# [Comedy, Drama]                  6
# [Comedy, Drama, Romance]         6
# [Drama, War]                     5
# [Animation, Comedy, Family]      4
# [Action, Crime, Drama]           4
# [Western]                        4
# [Adventure, Fantasy, Family]     4
# Name: genres, dtype: int64

# %%
top250movies_score['genres'].value_counts()[:5].sort_values().plot(kind = 'barh', figsize = (20,5))
plt.title('Top 5 Genres', fontsize = 20)
plt.xlabel('Movie Count', fontsize = 15)
plt.ylabel('Genres', fontsize = 15);

# %%
top250movies_score['popularity'].value_counts()
# Out:
# 51.645403     1
# 21.277073     1
# 8.863776      1
# 17.924927     1
# 14.140780     1
#              ..
# 213.849907    1
# 14.876086     1
# 7.903731      1
# 15.811921     1
# 89.887648     1
# Name: popularity, Length: 250, dtype: int64

# %%
top250movies_score.sort_values('popularity', ascending=False, inplace=True)
top10_popularity = top250movies_score.head(5)

# %%
base_color = sb.color_palette()[0]
sb.barplot(data = top10_popularity, x = 'popularity', y = 'original_title', color=base_color, errwidth = 0)
plt.title('Top 10 Popular Movies', fontsize = 20)
plt.xlabel('Popularity', fontsize = 15);
plt.ylabel('Movie Title', fontsize = 15);

# %%
top250movies_score['original_language'].value_counts()[:5].sort_values().plot(kind = 'barh', figsize = (20,5))
plt.title('Top 10 Languages', fontsize = 20)
plt.xlabel('Movie Count', fontsize = 15)
plt.ylabel('Language', fontsize = 15);

# %%
top250movies_score['production_countries'].value_counts()[:10].sort_values().plot(kind = 'barh', figsize = (20,5))
plt.title('Top 10 Production Countries', fontsize = 20)
plt.xlabel('Movie Count', fontsize = 15)
plt.ylabel('Production Country', fontsize = 15);

# %%
#split the column “production_countries” into multiple columns, one for each value in the list using tolist() function
production_countries = pd.DataFrame(top250movies_score['production_countries'].tolist(), columns = ['country1', 'country2', 'country3'])
production_countries
# Out:
#     country1 country2 country3
# 0         US     None     None
# 1         US     None     None
# 2         US     None     None
# 3         US     None     None
# 4         GB       US     None
# ..       ...      ...      ...
# 245       BE       DK       FR
# 246       US     None     None
# 247       SE     None     None
# 248       US     None     None
# 249       JP     None     None
#
# [250 rows x 3 columns]

# %%
# replace 'NaN' values with empty string
production_countries['country1'] = production_countries['country1'].fillna('')
production_countries['country2'] = production_countries['country2'].fillna('')
production_countries['country3'] = production_countries['country3'].fillna('')

# %% [markdown]
# # combine the three columns into one column (production_countries) with a separator
# production_countries['countries'] = production_countries['country1'] + production_countries['country2'] + production_countries['country3']

# %%
# combine the three columns into one column (production_countries) with a separator
production_countries['countries'] = production_countries['country1'].str.cat(production_countries[['country2', 'country3']], sep=' - ')

# %%
production_countries.head(20)
# Out:
#    country1 country2 country3     countries
# 0        US                        US -  -
# 1        US                        US -  -
# 2        US                        US -  -
# 3        US                        US -  -
# 4        GB       US             GB - US -
# 5        US       HK       GB  US - HK - GB
# 6        US                        US -  -
# 7        US                        US -  -
# 8        DE       US             DE - US -
# 9        US                        US -  -
# 10       GB       US             GB - US -
# 11       US                        US -  -
# 12       US                        US -  -
# 13       US                        US -  -
# 14       US                        US -  -
# 15       US                        US -  -
# 16       US                        US -  -
# 17       JP                        JP -  -
# 18       IT                        IT -  -
# 19       GB       US             GB - US -

# %%
production_countries.loc[production_countries['countries'] == 'GB - US - ', 'countries'] = 'US - GB - '

# %%
production_countries[production_countries['countries'] == 'GB - US - ']
# Out:
# Empty DataFrame
# Columns: [country1, country2, country3, countries]
# Index: []

# %%
production_countries['countries'].value_counts()[:5].sort_values().plot(kind = 'barh', figsize = (20,5))
plt.title('Top 10 Production Countries', fontsize = 20)
plt.xlabel('Movie Count', fontsize = 15)
plt.ylabel('Production Country', fontsize = 15);

# %%
production_countries.loc[production_countries['countries'] == 'US - - ', 'countries'] = 'US'
production_countries.loc[production_countries['countries'] == 'US - GB - ', 'countries'] = 'US-GB'
production_countries.loc[production_countries['countries'] == 'JP - - ', 'countries'] = 'JP'
production_countries.loc[production_countries['countries'] == 'GB - - ', 'countries'] = 'GB'
production_countries.loc[production_countries['countries'] == 'FR - US - ', 'countries'] = 'FR-US'
production_countries.loc[production_countries['countries'] == 'DE - - ', 'countries'] = 'DE'
production_countries.loc[production_countries['countries'] == 'NZ - US - ', 'countries'] = 'NZ-US'
production_countries.loc[production_countries['countries'] == 'KR - - ', 'countries'] = 'KR'
production_countries.loc[production_countries['countries'] == 'IT - - ', 'countries'] = 'IT'
production_countries.loc[production_countries['countries'] == 'AU - US - ', 'countries'] = 'AU-US'

# %%
production_countries.sample(20)
# Out:
#     country1 country2 country3     countries
# 172       US                        US -  -
# 200       IN       GB       US  IN - GB - US
# 169       IT       ES       DE  IT - ES - DE
# 101       US                        US -  -
# 84        US                        US -  -
# 106       US                        US -  -
# 166       US                        US -  -
# 117       US                        US -  -
# 148       GB       US                  US-GB
# 42        ES       US       MX  ES - US - MX
# 65        US                        US -  -
# 195       US                        US -  -
# 242       IN       AE       US  IN - AE - US
# 60        US                        US -  -
# 122       FR                        FR -  -
# 112       KR                        KR -  -
# 28        US       IT             US - IT -
# 135       CA       US             CA - US -
# 139       GB       US       FR  GB - US - FR
# 12        US                        US -  -

# %%
production_countries['countries'].value_counts()[:10].sort_values().plot(kind = 'barh', figsize = (20,5))
plt.title('Top 10 Production Countries', fontsize = 20)
plt.xlabel('Movie Count', fontsize = 15)
plt.ylabel('Production Country', fontsize = 15);

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   original_title        45466 non-null  object
#  1   overview              44512 non-null  object
#  2   revenue               45460 non-null  float64
#  3   budget                45466 non-null  object
#  4   genres                45466 non-null  object
#  5   original_language     45455 non-null  object
#  6   popularity            45461 non-null  object
#  7   vote_average          45460 non-null  float64
#  8   vote_count            45460 non-null  float64
#  9   production_countries  45463 non-null  object
# dtypes: float64(3), object(7)
# memory usage: 3.5+ MB

# %%
#Using Apply to search for substring in all dataframe columns
substring = 'jpg'
df_movies[df_movies.apply(lambda row: row.astype(str).str.contains(substring, case=False).any(), axis=1)]
# Out:
#                                  original_title  overview  revenue  \
# 19730  [{'iso_639_1': 'en', 'name': 'English'}]  Released      NaN
# 29503      [{'iso_639_1': 'ja', 'name': '日本語'}]  Released      NaN
# 35587  [{'iso_639_1': 'en', 'name': 'English'}]  Released      NaN
#
#                                  budget  \
# 19730  /ff9qCepilowshEtG2GYWwzt2bs4.jpg
# 29503  /zV8bHuSL6WXoD6FWogP9j4x80bL.jpg
# 35587  /zaSf5OG7V8X8gqFvly88zDdRm46.jpg
#
#                                                   genres original_language  \
# 19730  [{'name': 'Carousel Productions', 'id': 11176}...             104.0
# 29503  [{'name': 'Aniplex', 'id': 2883}, {'name': 'Go...              68.0
# 35587  [{'name': 'Odyssey Media', 'id': 17161}, {'nam...              82.0
#
#                   popularity  vote_average  vote_count production_countries
# 19730                    NaN           NaN         NaN                  6.0
# 29503                    NaN           NaN         NaN                  7.0
# 35587  Beware Of Frost Bites           NaN         NaN                  4.3

# %%
#replace string values under budget column to Nan
df_movies['budget'].replace('/ff9qCepilowshEtG2GYWwzt2bs4.jpg', np.NaN, inplace = True)
df_movies['budget'].replace('/zV8bHuSL6WXoD6FWogP9j4x80bL.jpg', np.NaN, inplace = True)
df_movies['budget'].replace('/zaSf5OG7V8X8gqFvly88zDdRm46.jpg', np.NaN, inplace = True)
# Out:
# C:\Users\Martin Kunth\anaconda3\lib\site-packages\pandas\core\generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
#Using Apply to search for substring in all dataframe columns
substring = 'jpg'
df_movies[df_movies.apply(lambda row: row.astype(str).str.contains(substring, case=False).any(), axis=1)]
# Out:
# Empty DataFrame
# Columns: [original_title, overview, revenue, budget, genres, original_language, popularity, vote_average, vote_count, production_countries]
# Index: []

# %%
# change data type of budget column from string to float
df_movies['budget'] = df_movies['budget'].astype(float)
# Out:
# C:\Users\MARTIN~1\AppData\Local\Temp/ipykernel_6276/2245891682.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_movies['budget'] = df_movies['budget'].astype(float)

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   original_title        45466 non-null  object
#  1   overview              44512 non-null  object
#  2   revenue               45460 non-null  float64
#  3   budget                45463 non-null  float64
#  4   genres                45466 non-null  object
#  5   original_language     45455 non-null  object
#  6   popularity            45461 non-null  object
#  7   vote_average          45460 non-null  float64
#  8   vote_count            45460 non-null  float64
#  9   production_countries  45463 non-null  object
# dtypes: float64(4), object(6)
# memory usage: 3.5+ MB

# %%
#Create a new column 'estimated profit' to store the estimazed profit of movies computed by subtracting
#the values in the budget column from the values in the revenue column and set the new column next to buget column
df_movies.insert(4, 'estimated_profit', df_movies['revenue'] - df_movies['budget'])
df_movies.head()
# Out:
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview      revenue      budget  \
# 0  Led by Woody, Andy's toys live happily in his ...  373554033.0  30000000.0
# 1  When siblings Judy and Peter discover an encha...  262797249.0  65000000.0
# 2  A family wedding reignites the ancient feud be...          0.0         0.0
# 3  Cheated on, mistreated and stepped on, the wom...   81452156.0  16000000.0
# 4  Just when George Banks has recovered from his ...   76578911.0         0.0
#
#    estimated_profit                                             genres  \
# 0       343554033.0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1       197797249.0  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2               0.0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3        65452156.0  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4        76578911.0                     [{'id': 35, 'name': 'Comedy'}]
#
#   original_language popularity  vote_average  vote_count  \
# 0                en  21.946943           7.7      5415.0
# 1                en  17.015539           6.9      2413.0
# 2                en    11.7129           6.5        92.0
# 3                en   3.859495           6.1        34.0
# 4                en   8.387519           5.7       173.0
#
#                                 production_countries
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   original_title        45466 non-null  object
#  1   overview              44512 non-null  object
#  2   revenue               45460 non-null  float64
#  3   budget                45463 non-null  float64
#  4   estimated_profit      45460 non-null  float64
#  5   genres                45466 non-null  object
#  6   original_language     45455 non-null  object
#  7   popularity            45461 non-null  object
#  8   vote_average          45460 non-null  float64
#  9   vote_count            45460 non-null  float64
#  10  production_countries  45463 non-null  object
# dtypes: float64(5), object(6)
# memory usage: 3.8+ MB

# %%
df_movies_sorted = df_movies.sort_values(by=['estimated_profit'], ascending=False)
df_movies_sorted.head(20)
# Out:
#                                       original_title  \
# 14551                                         Avatar
# 26555                   Star Wars: The Force Awakens
# 1639                                         Titanic
# 25084                                 Jurassic World
# 28830                                      Furious 7
# 17818                                   The Avengers
# 17437   Harry Potter and the Deathly Hallows: Part 2
# 26558                        Avengers: Age of Ultron
# 22110                                         Frozen
# 42222                           Beauty and the Beast
# 30700                                        Minions
# 7000   The Lord of the Rings: The Return of the King
# 20830                                     Iron Man 3
# 43255                        The Fate of the Furious
# 44009                                Despicable Me 3
# 17293                 Transformers: Dark of the Moon
# 19261                                        Skyfall
# 26567                     Captain America: Civil War
# 21161                                Despicable Me 2
# 23617                Transformers: Age of Extinction
#
#                                                 overview       revenue  \
# 14551  In the 22nd century, a paraplegic Marine is di...  2.787965e+09
# 26555  Thirty years after defeating the Galactic Empi...  2.068224e+09
# 1639   84 years later, a 101-year-old woman named Ros...  1.845034e+09
# 25084  Twenty-two years after the events of Jurassic ...  1.513529e+09
# 28830  Deckard Shaw seeks revenge against Dominic Tor...  1.506249e+09
# 17818  When an unexpected enemy emerges and threatens...  1.519558e+09
# 17437  Harry, Ron and Hermione continue their quest t...  1.342000e+09
# 26558  When Tony Stark tries to jumpstart a dormant p...  1.405404e+09
# 22110  Young princess Anna of Arendelle dreams about ...  1.274219e+09
# 42222  A live-action adaptation of Disney's version o...  1.262886e+09
# 30700  Minions Stuart, Kevin and Bob are recruited by...  1.156731e+09
# 7000   Aragorn is revealed as the heir to the ancient...  1.118889e+09
# 20830  When Tony Stark's world is torn apart by a for...  1.215440e+09
# 43255  When a mysterious woman seduces Dom into the w...  1.238765e+09
# 44009  Gru and his wife Lucy must stop former '80s ch...  1.020063e+09
# 17293  Sam Witwicky takes his first tenuous steps int...  1.123747e+09
# 19261  When Bond's latest assignment goes gravely wro...  1.108561e+09
# 26567  Following the events of Age of Ultron, the col...  1.153304e+09
# 21161  Gru is recruited by the Anti-Villain League to...  9.707619e+08
# 23617  As humanity picks up the pieces, following the...  1.091405e+09
#
#             budget  estimated_profit  \
# 14551  237000000.0      2.550965e+09
# 26555  245000000.0      1.823224e+09
# 1639   200000000.0      1.645034e+09
# 25084  150000000.0      1.363529e+09
# 28830  190000000.0      1.316249e+09
# 17818  220000000.0      1.299558e+09
# 17437  125000000.0      1.217000e+09
# 26558  280000000.0      1.125404e+09
# 22110  150000000.0      1.124219e+09
# 42222  160000000.0      1.102886e+09
# 30700   74000000.0      1.082731e+09
# 7000    94000000.0      1.024889e+09
# 20830  200000000.0      1.015440e+09
# 43255  250000000.0      9.887648e+08
# 44009   80000000.0      9.400634e+08
# 17293  195000000.0      9.287470e+08
# 19261  200000000.0      9.085610e+08
# 26567  250000000.0      9.033045e+08
# 21161   76000000.0      8.947619e+08
# 23617  210000000.0      8.814051e+08
#
#                                                   genres original_language  \
# 14551  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...                en
# 26555  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...                en
# 1639   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...                en
# 25084  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...                en
# 28830                     [{'id': 28, 'name': 'Action'}]                en
# 17818  [{'id': 878, 'name': 'Science Fiction'}, {'id'...                en
# 17437  [{'id': 10751, 'name': 'Family'}, {'id': 14, '...                en
# 26558  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...                en
# 22110  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...                en
# 42222  [{'id': 10751, 'name': 'Family'}, {'id': 14, '...                en
# 30700  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...                en
# 7000   [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...                en
# 20830  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...                en
# 43255  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...                en
# 44009  [{'id': 28, 'name': 'Action'}, {'id': 16, 'nam...                en
# 17293  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...                en
# 19261  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...                en
# 26567  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...                en
# 21161  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...                en
# 23617  [{'id': 878, 'name': 'Science Fiction'}, {'id'...                en
#
#        popularity  vote_average  vote_count  \
# 14551  185.070892           7.2     12114.0
# 26555   31.626013           7.5      7993.0
# 1639     26.88907           7.5      7770.0
# 25084   32.790475           6.5      8842.0
# 28830   27.275687           7.3      4253.0
# 17818   89.887648           7.4     12000.0
# 17437   24.990737           7.9      6141.0
# 26558    37.37942           7.3      6908.0
# 22110   24.248243           7.3      5440.0
# 42222  287.253654           6.8      5530.0
# 30700  547.488298           6.4      4729.0
# 7000    29.324358           8.1      8226.0
# 20830   23.721243           6.8      8951.0
# 43255   48.573287           6.8      3803.0
# 44009   36.631519           6.2      2002.0
# 17293    4.503505           6.1      3351.0
# 19261   20.309585           6.9      7718.0
# 26567  145.882135           7.1      7462.0
# 21161    24.82355           7.0      4729.0
# 23617   18.495599           5.8      3136.0
#
#                                     production_countries
# 14551  [{'iso_3166_1': 'US', 'name': 'United States o...
# 26555  [{'iso_3166_1': 'US', 'name': 'United States o...
# 1639   [{'iso_3166_1': 'US', 'name': 'United States o...
# 25084  [{'iso_3166_1': 'US', 'name': 'United States o...
# 28830  [{'iso_3166_1': 'JP', 'name': 'Japan'}, {'iso_...
# 17818  [{'iso_3166_1': 'US', 'name': 'United States o...
# 17437  [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...
# 26558  [{'iso_3166_1': 'US', 'name': 'United States o...
# 22110  [{'iso_3166_1': 'US', 'name': 'United States o...
# 42222  [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...
# 30700  [{'iso_3166_1': 'US', 'name': 'United States o...
# 7000   [{'iso_3166_1': 'NZ', 'name': 'New Zealand'}, ...
# 20830  [{'iso_3166_1': 'CN', 'name': 'China'}, {'iso_...
# 43255  [{'iso_3166_1': 'US', 'name': 'United States o...
# 44009  [{'iso_3166_1': 'US', 'name': 'United States o...
# 17293  [{'iso_3166_1': 'US', 'name': 'United States o...
# 19261  [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...
# 26567  [{'iso_3166_1': 'US', 'name': 'United States o...
# 21161  [{'iso_3166_1': 'US', 'name': 'United States o...
# 23617  [{'iso_3166_1': 'US', 'name': 'United States o...

# %%
top250movies_profit = df_movies_sorted[['original_title', 'genres', 'popularity', 'original_language', 
                                        'production_countries', 'revenue', 'budget', 'estimated_profit']].head(250)
top250movies_profit.head()
# Out:
#                      original_title  \
# 14551                        Avatar
# 26555  Star Wars: The Force Awakens
# 1639                        Titanic
# 25084                Jurassic World
# 28830                     Furious 7
#
#                                                   genres  popularity  \
# 14551  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...  185.070892
# 26555  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...   31.626013
# 1639   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...    26.88907
# 25084  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...   32.790475
# 28830                     [{'id': 28, 'name': 'Action'}]   27.275687
#
#       original_language                               production_countries  \
# 14551                en  [{'iso_3166_1': 'US', 'name': 'United States o...
# 26555                en  [{'iso_3166_1': 'US', 'name': 'United States o...
# 1639                 en  [{'iso_3166_1': 'US', 'name': 'United States o...
# 25084                en  [{'iso_3166_1': 'US', 'name': 'United States o...
# 28830                en  [{'iso_3166_1': 'JP', 'name': 'Japan'}, {'iso_...
#
#             revenue       budget  estimated_profit
# 14551  2.787965e+09  237000000.0      2.550965e+09
# 26555  2.068224e+09  245000000.0      1.823224e+09
# 1639   1.845034e+09  200000000.0      1.645034e+09
# 25084  1.513529e+09  150000000.0      1.363529e+09
# 28830  1.506249e+09  190000000.0      1.316249e+09

# %%
top250movies_profit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 250 entries, 14551 to 2006
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   original_title        250 non-null    object
#  1   genres                250 non-null    object
#  2   popularity            250 non-null    object
#  3   original_language     250 non-null    object
#  4   production_countries  250 non-null    object
#  5   revenue               250 non-null    float64
#  6   budget                250 non-null    float64
#  7   estimated_profit      250 non-null    float64
# dtypes: float64(3), object(5)
# memory usage: 17.6+ KB

# %%
top250movies_profit.describe()
# Out:
#             revenue        budget  estimated_profit
# count  2.500000e+02  2.500000e+02      2.500000e+02
# mean   6.777880e+08  1.184535e+08      5.593345e+08
# std    3.035510e+08  7.239554e+07      2.678445e+08
# min    3.180001e+08  0.000000e+00      3.050000e+08
# 25%    4.707962e+08  6.079000e+07      3.762153e+08
# 50%    6.069794e+08  1.175000e+08      4.853064e+08
# 75%    8.067463e+08  1.687500e+08      6.607069e+08
# max    2.787965e+09  3.800000e+08      2.550965e+09

# %%
top250movies_profit['estimated_profit'].describe().apply(lambda x: format(x, 'f'))
# Out:
# count           250.000000
# mean      559334473.096000
# std       267844469.537323
# min       305000000.000000
# 25%       376215349.750000
# 50%       485306433.000000
# 75%       660706865.500000
# max      2550965087.000000
# Name: estimated_profit, dtype: object

# %%
top250movies_profit['popularity'] = top250movies_profit['popularity'].astype(float)
top250movies_profit['popularity'].describe()
# Out:
# count    250.000000
# mean      30.204924
# std       50.084681
# min        0.702543
# 25%       13.876591
# 50%       19.083534
# 75%       26.576124
# max      547.488298
# Name: popularity, dtype: float64

# %%
bins = np.arange(0, top250movies_profit['popularity'].max()+0.7, 2)
plt.figure(figsize=[10, 8])
plt.hist(data=top250movies_profit, x = 'popularity', bins = bins);
plt.xlabel('Popularity', size = 12);
plt.ylabel('Number of Movies', size = 12)
plt.title('Popularity Distribution of the Top 250 Movies based on Estimated Profit (US$)', size = 15);

# %%
# create function to extract genre and country by converting from json list into list of strings

def json_to_arr(cell, wanted = 'name'):
    cell = literal_eval(cell)
    if cell == [] or (isinstance(cell, float) and cell.isna()):
        return np.nan
    result = []
    counter = 0
    for element in cell:
        if counter < 3:
            result.append(element[wanted])
            counter += 1
        else:
            break
    return result[:3]

# %%
top250movies_profit[['genres']] = top250movies_profit[['genres']].applymap(json_to_arr)
top250movies_profit[['production_countries']] = top250movies_profit[['production_countries']].applymap(lambda row:
                                                                                json_to_arr(row, "iso_3166_1"))

# %%
top250movies_profit.to_csv('top250movies_profit.csv', index = False)

# %%
top250movies_profit['genres'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [Action, Adventure, Fantasy]            12
# [Animation, Comedy, Family]             11
# [Action, Adventure, Science Fiction]    10
# [Animation, Family]                      8
# [Adventure, Action, Science Fiction]     8
#                                         ..
# [War, Action]                            1
# [Adventure, Family, Animation]           1
# [Adventure, Science Fiction]             1
# [Comedy, Science Fiction, Fantasy]       1
# [Horror, Thriller]                       1
# Name: genres, Length: 129, dtype: int64

# %%
top250movies_profit['production_countries'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [US]            176
# [GB, US]         27
# [NZ, US]          6
# [CN, US]          4
# [DE, US]          4
# [DE, GB, US]      3
# [US, GB]          2
# [JP, US]          2
# [FR]              2
# [AU, US]          2
# [CA, US]          2
# [NZ, US, DE]      1
# [JP]              1
# [CN, HK]          1
# [AU]              1
# [US, MT]          1
# [AU, GB, US]      1
# [IN, GB, US]      1
# [US, MT, GB]      1
# [CA, US, AU]      1
# [IT, GB, US]      1
# [CA, HK, TW]      1
# [GB]              1
# [NL, FR, GB]      1
# [FR, US]          1
# [US, TW, GB]      1
# [CN]              1
# [CA, US, GB]      1
# [CZ, US, AE]      1
# [US, MT, FR]      1
# [JP, US, NZ]      1
# Name: production_countries, dtype: int64

# %%
top250movies_profit.head()
# Out:
#                      original_title                                genres  \
# 14551                        Avatar          [Action, Adventure, Fantasy]
# 26555  Star Wars: The Force Awakens  [Action, Adventure, Science Fiction]
# 1639                        Titanic            [Drama, Romance, Thriller]
# 25084                Jurassic World  [Action, Adventure, Science Fiction]
# 28830                     Furious 7                              [Action]
#
#        popularity original_language production_countries       revenue  \
# 14551  185.070892                en             [US, GB]  2.787965e+09
# 26555   31.626013                en                 [US]  2.068224e+09
# 1639    26.889070                en                 [US]  1.845034e+09
# 25084   32.790475                en                 [US]  1.513529e+09
# 28830   27.275687                en             [JP, US]  1.506249e+09
#
#             budget  estimated_profit
# 14551  237000000.0      2.550965e+09
# 26555  245000000.0      1.823224e+09
# 1639   200000000.0      1.645034e+09
# 25084  150000000.0      1.363529e+09
# 28830  190000000.0      1.316249e+09

# %%
top250movies_profit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 250 entries, 14551 to 2006
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   original_title        250 non-null    object
#  1   genres                250 non-null    object
#  2   popularity            250 non-null    float64
#  3   original_language     250 non-null    object
#  4   production_countries  250 non-null    object
#  5   revenue               250 non-null    float64
#  6   budget                250 non-null    float64
#  7   estimated_profit      250 non-null    float64
# dtypes: float64(4), object(4)
# memory usage: 17.6+ KB

# %%
top250movies_profit['original_language'].unique()
# Out:
# array(['en', 'fr', 'ja', 'zh'], dtype=object)

# %%
top250movies_profit.loc[top250movies_profit['original_language'] == 'en', 'original_language'] = 'English'
top250movies_profit.loc[top250movies_profit['original_language'] == 'fr', 'original_language'] = 'French'
top250movies_profit.loc[top250movies_profit['original_language'] == 'ja', 'original_language'] = 'Japanese'
top250movies_profit.loc[top250movies_profit['original_language'] == 'zh', 'original_language'] = 'Chinese(ZH)'
top250movies_profit['original_language'].unique()
# Out:
# array(['English', 'French', 'Japanese', 'Chinese(ZH)'], dtype=object)

# %%
top250movies_profit.sample(20)
# Out:
#                                           original_title  \
# 7909                                        Spider-Man 2
# 15153                                         Iron Man 2
# 19051                 Madagascar 3: Europe's Most Wanted
# 19129                             The Amazing Spider-Man
# 26566                     Guardians of the Galaxy Vol. 2
# 10597  The Chronicles of Narnia: The Lion, the Witch ...
# 23472                 Mission: Impossible - Rogue Nation
# 7717                                             Shrek 2
# 30315                                         Inside Out
# 19261                                            Skyfall
# 19735                                         Life of Pi
# 18244                                   The Hunger Games
# 15408                         The Twilight Saga: Eclipse
# 17293                     Transformers: Dark of the Moon
# 583                                   Dances with Wolves
# 23437                                         Maleficent
# 4142                                   The Mummy Returns
# 1888                                        The Exorcist
# 11404                                      Casino Royale
# 19814          The Twilight Saga: Breaking Dawn - Part 2
#
#                                       genres  popularity original_language  \
# 7909            [Action, Adventure, Fantasy]   10.834506           English
# 15153   [Adventure, Action, Science Fiction]   19.083344           English
# 19051                    [Animation, Family]   13.829042           English
# 19129           [Action, Adventure, Fantasy]   31.102267           English
# 26566            [Action, Adventure, Comedy]  185.330992           English
# 10597           [Adventure, Family, Fantasy]   18.135420           English
# 23472          [Action, Adventure, Thriller]   17.836882           English
# 7717          [Adventure, Animation, Comedy]   16.229860           English
# 30315             [Drama, Comedy, Animation]   23.985587           English
# 19261          [Action, Adventure, Thriller]   20.309585           English
# 19735             [Adventure, Drama, Action]   14.045042           English
# 18244  [Science Fiction, Adventure, Fantasy]   20.031667           English
# 15408            [Adventure, Fantasy, Drama]   34.047399           English
# 17293   [Action, Science Fiction, Adventure]    4.503505           English
# 583              [Adventure, Drama, Western]   11.654349           English
# 23437           [Fantasy, Adventure, Action]   19.467404           English
# 4142            [Adventure, Action, Fantasy]   16.945657           English
# 1888               [Drama, Horror, Thriller]   12.137595           English
# 11404          [Adventure, Action, Thriller]   23.065078           English
# 19814            [Adventure, Fantasy, Drama]   26.080995           English
#
#       production_countries       revenue       budget  estimated_profit
# 7909                  [US]  7.837663e+08  200000000.0       583766341.0
# 15153                 [US]  6.239333e+08  200000000.0       423933331.0
# 19051                 [US]  7.469213e+08  145000000.0       601921274.0
# 19129                 [US]  7.522159e+08  215000000.0       537215857.0
# 26566                 [US]  8.634161e+08  200000000.0       663416141.0
# 10597             [GB, US]  7.488070e+08  180000000.0       568806957.0
# 23472             [CN, US]  6.823301e+08  150000000.0       532330139.0
# 7717                  [US]  9.198388e+08  150000000.0       769838758.0
# 30315                 [US]  8.576112e+08  175000000.0       682611174.0
# 19261             [GB, US]  1.108561e+09  200000000.0       908561013.0
# 19735         [US, TW, GB]  6.090166e+08  120000000.0       489016565.0
# 18244                 [US]  6.912107e+08   75000000.0       616210692.0
# 15408                 [US]  6.984913e+08   68000000.0       630491347.0
# 17293                 [US]  1.123747e+09  195000000.0       928746996.0
# 583               [GB, US]  4.242088e+08   22000000.0       402208848.0
# 23437                 [US]  7.585398e+08  180000000.0       578539785.0
# 4142                  [US]  4.330133e+08   98000000.0       335013274.0
# 1888                  [US]  4.413061e+08    8000000.0       433306145.0
# 11404         [IT, GB, US]  5.990460e+08  150000000.0       449045960.0
# 19814                 [US]  8.290000e+08  120000000.0       709000000.0

# %%
top250movies_profit['genres'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [Action, Adventure, Fantasy]            12
# [Animation, Comedy, Family]             11
# [Action, Adventure, Science Fiction]    10
# [Animation, Family]                      8
# [Adventure, Action, Science Fiction]     8
#                                         ..
# [War, Action]                            1
# [Adventure, Family, Animation]           1
# [Adventure, Science Fiction]             1
# [Comedy, Science Fiction, Fantasy]       1
# [Horror, Thriller]                       1
# Name: genres, Length: 129, dtype: int64

# %%
top250movies_profit['genres'].value_counts()[:5].sort_values().plot(kind = 'barh', figsize = (20,5))
plt.title('Top 10 Genres', fontsize = 20)
plt.xlabel('Movie Count', fontsize = 15)
plt.ylabel('Genres', fontsize = 15);

# %%
top250movies_profit.sort_values('popularity', ascending=False, inplace=True)
top10_popular_movies_by_profit = top250movies_profit.head(5)

# %%
base_color = sb.color_palette()[0]
sb.barplot(data = top10_popular_movies_by_profit, x = 'popularity', y = 'original_title', color=base_color, errwidth = 0)
plt.title('Top 10 Popular Movies', fontsize = 20)
plt.xlabel('Popularity', fontsize = 15);
plt.ylabel('Movie Title', fontsize = 15);

# %%
top250movies_profit['original_language'].value_counts()[:10].sort_values().plot(kind = 'barh', figsize = (20,5))
plt.title('Top Languages', fontsize = 20)
plt.xlabel('Movie Count', fontsize = 15)
plt.ylabel('Language', fontsize = 15);

# %%
top250movies_profit['production_countries'].value_counts()[:10].sort_values().plot(kind = 'barh', figsize = (20,5))
plt.title('Top 10 Production Countries', fontsize = 20)
plt.xlabel('Movie Count', fontsize = 15)
plt.ylabel('Country', fontsize = 15);

# %%
#split the column “production_countries” into multiple columns, one for each value in the list using tolist() function
top_prod_countries_profit= pd.DataFrame(top250movies_profit['production_countries'].tolist(), columns = ['country1', 'country2', 'country3'])
top_prod_countries_profit
# Out:
#     country1 country2 country3
# 0         US     None     None
# 1         US     None     None
# 2         GB       US     None
# 3         US     None     None
# 4         US     None     None
# ..       ...      ...      ...
# 245       US     None     None
# 246       US     None     None
# 247       US     None     None
# 248       US     None     None
# 249       US     None     None
#
# [250 rows x 3 columns]

# %%
# replace 'NaN' values with empty string
top_prod_countries_profit['country1'] = top_prod_countries_profit['country1'].fillna('')
top_prod_countries_profit['country2'] = top_prod_countries_profit['country2'].fillna('')
top_prod_countries_profit['country3'] = top_prod_countries_profit['country3'].fillna('')
top_prod_countries_profit
# Out:
#     country1 country2 country3
# 0         US
# 1         US
# 2         GB       US
# 3         US
# 4         US
# ..       ...      ...      ...
# 245       US
# 246       US
# 247       US
# 248       US
# 249       US
#
# [250 rows x 3 columns]

# %%
# combine the three columns into one column (production_countries) with a separator
top_prod_countries_profit['countries'] = top_prod_countries_profit['country1'].str.cat(top_prod_countries_profit[['country2', 'country3']], sep='-')
top_prod_countries_profit.head(20)
# Out:
#    country1 country2 country3 countries
# 0        US                        US--
# 1        US                        US--
# 2        GB       US             GB-US-
# 3        US                        US--
# 4        US                        US--
# 5        US                        US--
# 6        US       GB             US-GB-
# 7        US                        US--
# 8        US                        US--
# 9        US                        US--
# 10       US                        US--
# 11       GB       US             GB-US-
# 12       US                        US--
# 13       US                        US--
# 14       US                        US--
# 15       US                        US--
# 16       GB       US             GB-US-
# 17       US                        US--
# 18       US                        US--
# 19       US                        US--

# %%
top_prod_countries_profit.loc[top_prod_countries_profit['countries'] == 'GB-US-', 'countries'] = 'US-GB-'
top_prod_countries_profit[top_prod_countries_profit['countries'] == 'GB-US-']
# Out:
# Empty DataFrame
# Columns: [country1, country2, country3, countries]
# Index: []

# %%
top_prod_countries_profit[top_prod_countries_profit['countries'] == 'US-GB-']
# Out:
#     country1 country2 country3 countries
# 2         GB       US             US-GB-
# 6         US       GB             US-GB-
# 11        GB       US             US-GB-
# 16        GB       US             US-GB-
# 24        GB       US             US-GB-
# 26        GB       US             US-GB-
# 53        GB       US             US-GB-
# 55        GB       US             US-GB-
# 56        GB       US             US-GB-
# 67        GB       US             US-GB-
# 74        GB       US             US-GB-
# 75        GB       US             US-GB-
# 76        GB       US             US-GB-
# 85        GB       US             US-GB-
# 87        GB       US             US-GB-
# 98        GB       US             US-GB-
# 105       GB       US             US-GB-
# 111       GB       US             US-GB-
# 123       GB       US             US-GB-
# 124       GB       US             US-GB-
# 130       GB       US             US-GB-
# 131       GB       US             US-GB-
# 135       GB       US             US-GB-
# 141       GB       US             US-GB-
# 148       US       GB             US-GB-
# 190       GB       US             US-GB-
# 191       GB       US             US-GB-
# 213       GB       US             US-GB-
# 233       GB       US             US-GB-

# %%
top_prod_countries_profit['countries'].value_counts()[:5].sort_values().plot(kind = 'barh', figsize = (20,5))
plt.title('Top 10 Production Countries', fontsize = 20)
plt.xlabel('Movie Count', fontsize = 15)
plt.ylabel('Country', fontsize = 15);
